# %%
import re
import requests
import math
import time
from collections import defaultdict

import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from nltk.corpus import stopwords

# %%
name_file = 'conn_bkm'
connections = pd.read_csv(name_file+'.csv')

# %%
cachedStopWords = stopwords.words("english")

def text_cleaning(x, cachedStopWords=cachedStopWords):
    """Clean text: remove non alphabetical words, stopwords and duplicate words"""
    x = re.sub(r'[-\\/()]', ' ', x)
    x = re.sub(r'[^a-zA-Z ]', '', x)
    x = x.lower()
    word_list =[]
    
    # make copy of stopwords
    words = list(cachedStopWords)
    for word in x.encode('utf-8').split():
        if word not in words:
            if word[-1]=='s':
                word = word[:-1]
                word = word.decode('utf-8')
                #word = word[1:]
                word_list.append(word)
                words += [word]
            else:
                word = word.decode('utf-8')
                #word = word[1:]
                word_list.append(word)
                words += [word]
    
    return ' '.join(word_list)


##clean the test
connections['Company'] = connections['Company'].map(str).map(lambda x: text_cleaning(x))

# %%
class jobListing():
    def __init__(self):
        self.url = 'https://www.careerbuilder.co.in/jobsearch'
        self.headers = {'User-Agent':  """Mozilla/5.0"""}
        self.detail = defaultdict(list)
        
    def get_soups(self, q = '',loc = '',pg=1, **kwargs ):
        """Get html of jobs page
        Params
        -------
        q: search query can be company number or title or any word in description
        loc: location
        kwargs: https://www.careerbuilder.co.in/jobsearch"""
        
        params = locals()
        params.pop('self', None)
        
        if 'kwargs' in params.keys():
            params.pop('kwargs',None)
            self.params = {**params, **kwargs}
            
        self.params_list = ''
        for i, j in self.params.items():
            if j !='':
                self.params_list += i + ': ' + str(j) + ' | '
            
        r = requests.get(self.url, headers =self.headers, params=self.params )
        self.soup = BeautifulSoup(r.content, 'lxml')
        self.soup_posting = self.soup.find_all(attrs={'class':'job-info'})
        print(self.params_list)
        print(r.url)
    
    @staticmethod
    def _get_number(x, get_last = False):
        x = re.findall(r'\d+', x)
        return int(x[0])
    
    def total_jobs(self):
        job_number = self.soup.find(attrs= {'class':'top-bloc with-button-filter'}).get_text().strip()
        no_jobs = self._get_number(job_number, get_last = True)
        print("Total jobs found {}.".format(no_jobs))
        if no_jobs>50:
            self.pages = [i for i in range(1,math.ceil(no_jobs/50)+1)]
        elif no_jobs == 0:
            self.pages = 0
        else:
            self.pages = 0
        
    def get_jobs(self):
        for job in self.soup_posting:
            self.detail['title'].append(job.find(attrs = {'itemprop':'title'}).get_text().strip())
            self.detail['employmentType'].append(job.find(attrs = {'itemprop':'employmentType'}).get_text().strip())
            self.detail['job_url'].append(job.find(attrs = {'class':'job-title'}).get('href'))
            self.detail['company'].append(job.find(attrs = {'itemprop':'hiringOrganization'}).get_text().strip())
            self.detail['salary'].append(job.find(attrs = {'itemprop':'baseSalary'}).get_text().strip())
            self.detail['location'].append(job.find(attrs = {'itemprop':'jobLocation'}).get_text().strip())
            self.detail['summary'].append(job.find(attrs = {'class':'description'}).get_text().strip())
            date = job.find(attrs = {'class':'date'}).get_text().strip()
            self.detail['date'].append(self._get_number(date))
            self.detail['query'].append(self.params_list)
            self.detail['company_q'].append(self.params['q'])
            
    def get_all_jobs(self,  q = '',loc = '',pg=1, **kwargs):
        
        #get number of pages in result
        self.get_soups(q=q, loc = loc, pg = pg)
        try:
            self.total_jobs()
#             time.sleep(1)
            if self.pages == 0:
                print('No jobs..\nTrying next item in list if any..\n '.format(self.params_list))
            else:
                for i in self.pages:
                    print("Started scraping...")
                    self.get_soups(q=q, loc = loc, pg = i)
                    self.get_jobs()
        except:
            print('No jobs..\nTrying next item in list if any..\n '.format(self.params_list))

# %%
jobs_india =jobListing()
for i in set(connections['Company']):
    jobs_india.get_all_jobs(q=i)
df = pd.DataFrame(jobs_india.detail)
# Out:
# pg: 1 |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: bnp paribas corporate and institutional banking |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=bnp+paribas+corporate+and+institutional+banking
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: cloudfactory |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=cloudfactory
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: naseeb online services pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=naseeb+online+services+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: jagadamba motors heavy equipment |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=jagadamba+motors+heavy+equipment
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: jamboree education private limited |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=jamboree+education+private+limited
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: society of industrial engineering students nepal |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=society+of+industrial+engineering+students+nepal
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: vishal group united distributor nepal |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=vishal+group+united+distributor+nepal
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: froxjob executive jobs in nepal |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=froxjob+executive+jobs+in+nepal
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=microsoft
# Total jobs found 777.
# Started scraping...
# pg: 1 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=microsoft
# Started scraping...
# pg: 2 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=2&loc=&q=microsoft
# Started scraping...
# pg: 3 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=3&loc=&q=microsoft
# Started scraping...
# pg: 4 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=4&loc=&q=microsoft
# Started scraping...
# pg: 5 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=5&loc=&q=microsoft
# Started scraping...
# pg: 6 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=6&loc=&q=microsoft
# Started scraping...
# pg: 7 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=7&loc=&q=microsoft
# Started scraping...
# pg: 8 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=8&loc=&q=microsoft
# Started scraping...
# pg: 9 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=9&loc=&q=microsoft
# Started scraping...
# pg: 10 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=10&loc=&q=microsoft
# Started scraping...
# pg: 11 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=11&loc=&q=microsoft
# Started scraping...
# pg: 12 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=12&loc=&q=microsoft
# Started scraping...
# pg: 13 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=13&loc=&q=microsoft
# Started scraping...
# pg: 14 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=14&loc=&q=microsoft
# Started scraping...
# pg: 15 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=15&loc=&q=microsoft
# Started scraping...
# pg: 16 | q: microsoft |
# https://www.careerbuilder.co.in/jobsearch?pg=16&loc=&q=microsoft
# pg: 1 | q: the university of texas at arlington |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=the+university+of+texas+at+arlington
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: esewa fonepay |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=esewa+fonepay
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: edreams odigeo |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=edreams+odigeo
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: federation of nepalese chamber of commerce and industry |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=federation+of+nepalese+chamber+of+commerce+and+industry
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: aaron sales |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=aaron+sales
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: growth sellers consultancy pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=growth+sellers+consultancy+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: emerald education foundation |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=emerald+education+foundation
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: blogger blogspot |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=blogger+blogspot
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: microsoft student partners of nepal |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=microsoft+student+partners+of+nepal
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: uniting youths nepal |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=uniting+youths+nepal
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: lifeline nepal |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=lifeline+nepal
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: tuladhar metal works |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=tuladhar+metal+works
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: brbhandari associates |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=brbhandari+associates
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: laxmi group |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=laxmi+group
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: thapathali campus |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=thapathali+campus
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: himal refrigeration and electrical industries pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=himal+refrigeration+and+electrical+industries+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: aryaai |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=aryaai
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: cg cement |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=cg+cement
# Total jobs found 1.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: mukti energy |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=mukti+energy
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: ohio university |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=ohio+university
# Total jobs found 5.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: global founders capital |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=global+founders+capital
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: neupane law associates |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=neupane+law+associates
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: radio nepal singh darbar kathmandu |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=radio+nepal+singh+darbar+kathmandu
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: british council |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=british+council
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: linchhu |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=linchhu
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: industrial assessment center oregon state university |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=industrial+assessment+center+oregon+state+university
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: chhito express courier |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=chhito+express+courier
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: ignou |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=ignou
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: united embassy youth council nepal |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=united+embassy+youth+council+nepal
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: fif engineering llc |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=fif+engineering+llc
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: wwwmytripnepalcom holding company sanskriti infoedge pvtltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=wwwmytripnepalcom+holding+company+sanskriti+infoedge+pvtltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: upwork |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=upwork
# Total jobs found 111.
# Started scraping...
# pg: 1 | q: upwork |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=upwork
# Started scraping...
# pg: 2 | q: upwork |
# https://www.careerbuilder.co.in/jobsearch?pg=2&loc=&q=upwork
# Started scraping...
# pg: 3 | q: upwork |
# https://www.careerbuilder.co.in/jobsearch?pg=3&loc=&q=upwork
# pg: 1 | q: sipradi trading pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=sipradi+trading+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: sabaiko group pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=sabaiko+group+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: goldstar shoes kiran shoes manufacturers |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=goldstar+shoes+kiran+shoes+manufacturers
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: oregon state university |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=oregon+state+university
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: maw enterprises pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=maw+enterprises+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: cogent data solutions llc |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=cogent+data+solutions+llc
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: pagoda labs |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=pagoda+labs
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: daraz kaymu pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=daraz+kaymu+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: bao rui tong steel pipe industry group |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=bao+rui+tong+steel+pipe+industry+group
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: weblink nepal it institute pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=weblink+nepal+it+institute+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=non
# Total jobs found 1037.
# Started scraping...
# pg: 1 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=non
# Started scraping...
# pg: 2 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=2&loc=&q=non
# Started scraping...
# pg: 3 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=3&loc=&q=non
# Started scraping...
# pg: 4 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=4&loc=&q=non
# Started scraping...
# pg: 5 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=5&loc=&q=non
# Started scraping...
# pg: 6 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=6&loc=&q=non
# Started scraping...
# pg: 7 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=7&loc=&q=non
# Started scraping...
# pg: 8 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=8&loc=&q=non
# Started scraping...
# pg: 9 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=9&loc=&q=non
# Started scraping...
# pg: 10 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=10&loc=&q=non
# Started scraping...
# pg: 11 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=11&loc=&q=non
# Started scraping...
# pg: 12 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=12&loc=&q=non
# Started scraping...
# pg: 13 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=13&loc=&q=non
# Started scraping...
# pg: 14 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=14&loc=&q=non
# Started scraping...
# pg: 15 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=15&loc=&q=non
# Started scraping...
# pg: 16 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=16&loc=&q=non
# Started scraping...
# pg: 17 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=17&loc=&q=non
# Started scraping...
# pg: 18 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=18&loc=&q=non
# Started scraping...
# pg: 19 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=19&loc=&q=non
# Started scraping...
# pg: 20 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=20&loc=&q=non
# Started scraping...
# pg: 21 | q: non |
# https://www.careerbuilder.co.in/jobsearch?pg=21&loc=&q=non
# pg: 1 | q: towa engineering nepal pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=towa+engineering+nepal+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: wiseyak inc |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=wiseyak+inc
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: industrial engineering department |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=industrial+engineering+department
# Total jobs found 74.
# Started scraping...
# pg: 1 | q: industrial engineering department |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=industrial+engineering+department
# Started scraping...
# pg: 2 | q: industrial engineering department |
# https://www.careerbuilder.co.in/jobsearch?pg=2&loc=&q=industrial+engineering+department
# pg: 1 | q: deurali jaanta pharmaceuticals pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=deurali+jaanta+pharmaceuticals+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: mancer consulting services |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=mancer+consulting+services
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: mount talent consulting |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=mount+talent+consulting
# Total jobs found 98.
# Started scraping...
# pg: 1 | q: mount talent consulting |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=mount+talent+consulting
# Started scraping...
# pg: 2 | q: mount talent consulting |
# https://www.careerbuilder.co.in/jobsearch?pg=2&loc=&q=mount+talent+consulting
# pg: 1 | q: the real canadian superstore |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=the+real+canadian+superstore
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: jbm international pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=jbm+international+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: frontline consult p ltd froxjobcom |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=frontline+consult+p+ltd+froxjobcom
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: abu dhabi uae |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=abu+dhabi+uae
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: tiger brewery pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=tiger+brewery+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: kumarijobcom jobs in nepal |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=kumarijobcom+jobs+in+nepal
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: research assistant at university college of southeast norway |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=research+assistant+at+university+college+of+southeast+norway
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: beauty box nepal pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=beauty+box+nepal+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: itonics shaping innovation |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=itonics+shaping+innovation
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: rotaract club of jawlakhel manjushree |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=rotaract+club+of+jawlakhel+manjushree
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: laxmi intercontinental pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=laxmi+intercontinental+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: fashion delicacy |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=fashion+delicacy
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: sanima life insurance limited |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=sanima+life+insurance+limited
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: gogazzab p ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=gogazzab+p+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: hebron school |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=hebron+school
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: reiansu taxi sewa |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=reiansu+taxi+sewa
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: new york cakes |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=new+york+cakes
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: stallion international |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=stallion+international
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: froxjob |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=froxjob
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: reliance trade international pvtltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=reliance+trade+international+pvtltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: stefanini |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=stefanini
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: ap tv |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=ap+tv
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: panda retail company savola group |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=panda+retail+company+savola+group
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: smart telecom pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=smart+telecom+pvt+ltd
# Total jobs found 8.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: bibekshil sajha party |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=bibekshil+sajha+party
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: future works building solution pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=future+works+building+solution+pvt+ltd
# Total jobs found 13.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: power planet |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=power+planet
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: thakral one |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=thakral+one
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: daraz kaymu nepal pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=daraz+kaymu+nepal+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: pioneer solutions llc |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=pioneer+solutions+llc
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: management association of nepal |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=management+association+of+nepal
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: sustainable industrial development and entrepreneurial empowerment centre nepal |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=sustainable+industrial+development+and+entrepreneurial+empowerment+centre+nepal
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: zener technologies |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=zener+technologies
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: institute of engineeringthapathali campus |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=institute+of+engineeringthapathali+campus
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: civil group |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=civil+group
# Total jobs found 10.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: rawabi united safety services co ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=rawabi+united+safety+services+co+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: zen rooms |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=zen+rooms
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: la belle assiette |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=la+belle+assiette
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: united syndicate pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=united+syndicate+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: marphatech |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=marphatech
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: airtech industries p ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=airtech+industries+p+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: technomax pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=technomax+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: work around |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=work+around
# Total jobs found 362.
# Started scraping...
# pg: 1 | q: work around |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=work+around
# Started scraping...
# pg: 2 | q: work around |
# https://www.careerbuilder.co.in/jobsearch?pg=2&loc=&q=work+around
# Started scraping...
# pg: 3 | q: work around |
# https://www.careerbuilder.co.in/jobsearch?pg=3&loc=&q=work+around
# Started scraping...
# pg: 4 | q: work around |
# https://www.careerbuilder.co.in/jobsearch?pg=4&loc=&q=work+around
# Started scraping...
# pg: 5 | q: work around |
# https://www.careerbuilder.co.in/jobsearch?pg=5&loc=&q=work+around
# Started scraping...
# pg: 6 | q: work around |
# https://www.careerbuilder.co.in/jobsearch?pg=6&loc=&q=work+around
# Started scraping...
# pg: 7 | q: work around |
# https://www.careerbuilder.co.in/jobsearch?pg=7&loc=&q=work+around
# Started scraping...
# pg: 8 | q: work around |
# https://www.careerbuilder.co.in/jobsearch?pg=8&loc=&q=work+around
# pg: 1 | q: l i service pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=l+i+service+pvt+ltd
# Total jobs found 5.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: everjobs |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=everjobs
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: perfect air cool eng |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=perfect+air+cool+eng
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: dinesh kc associates chartered accountants |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=dinesh+kc+associates+chartered+accountants
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: bnb groups hospitality services |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=bnb+groups+hospitality+services
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: talentnepal hr consulting |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=talentnepal+hr+consulting
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: rocket internet se |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=rocket+internet+se
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: nepal airlines corporation |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=nepal+airlines+corporation
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: international finance cooperation |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=international+finance+cooperation
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: baniya nirman sewa |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=baniya+nirman+sewa
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=google
# Total jobs found 769.
# Started scraping...
# pg: 1 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=google
# Started scraping...
# pg: 2 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=2&loc=&q=google
# Started scraping...
# pg: 3 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=3&loc=&q=google
# Started scraping...
# pg: 4 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=4&loc=&q=google
# Started scraping...
# pg: 5 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=5&loc=&q=google
# Started scraping...
# pg: 6 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=6&loc=&q=google
# Started scraping...
# pg: 7 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=7&loc=&q=google
# Started scraping...
# pg: 8 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=8&loc=&q=google
# Started scraping...
# pg: 9 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=9&loc=&q=google
# Started scraping...
# pg: 10 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=10&loc=&q=google
# Started scraping...
# pg: 11 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=11&loc=&q=google
# Started scraping...
# pg: 12 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=12&loc=&q=google
# Started scraping...
# pg: 13 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=13&loc=&q=google
# Started scraping...
# pg: 14 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=14&loc=&q=google
# Started scraping...
# pg: 15 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=15&loc=&q=google
# Started scraping...
# pg: 16 | q: google |
# https://www.careerbuilder.co.in/jobsearch?pg=16&loc=&q=google
# pg: 1 | q: nepal reinsurance co ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=nepal+reinsurance+co+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: eurasia institute germany |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=eurasia+institute+germany
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: chanceco |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=chanceco
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: buddha air |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=buddha+air
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: top nepal international pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=top+nepal+international+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: engineering platform pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=engineering+platform+pvt+ltd
# Total jobs found 92.
# Started scraping...
# pg: 1 | q: engineering platform pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=engineering+platform+pvt+ltd
# Started scraping...
# pg: 2 | q: engineering platform pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=2&loc=&q=engineering+platform+pvt+ltd
# pg: 1 | q: bidhee |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=bidhee
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: chaudhary group |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=chaudhary+group
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: advanced academy |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=advanced+academy
# Total jobs found 2.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: youth for blood |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=youth+for+blood
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: mgs and associates |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=mgs+and+associates
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: daraz asia |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=daraz+asia
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: amtrak |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=amtrak
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: renu associates pty ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=renu+associates+pty+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: control desk |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=control+desk
# Total jobs found 18.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: acme hosting |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=acme+hosting
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: nan |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=nan
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: nepal electricity authority |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=nepal+electricity+authority
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: management student assotiation of nepal msan |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=management+student+assotiation+of+nepal+msan
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: smart data solutions |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=smart+data+solutions
# Total jobs found 22.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: berger paints nepal |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=berger+paints+nepal
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: zong cmpak ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=zong+cmpak+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: bikas udhyami |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=bikas+udhyami
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: kantipur digital corp |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=kantipur+digital+corp
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: strategic lobbying consultants |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=strategic+lobbying+consultants
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: kantipurjobcom |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=kantipurjobcom
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: rapid courier pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=rapid+courier+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: dhaasoo deals pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=dhaasoo+deals+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: cnbc tv |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=cnbc+tv
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: kpa |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=kpa
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: foto hollywood |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=foto+hollywood
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: student |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=student
# Total jobs found 662.
# Started scraping...
# pg: 1 | q: student |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=student
# Started scraping...
# pg: 2 | q: student |
# https://www.careerbuilder.co.in/jobsearch?pg=2&loc=&q=student
# Started scraping...
# pg: 3 | q: student |
# https://www.careerbuilder.co.in/jobsearch?pg=3&loc=&q=student
# Started scraping...
# pg: 4 | q: student |
# https://www.careerbuilder.co.in/jobsearch?pg=4&loc=&q=student
# Started scraping...
# pg: 5 | q: student |
# https://www.careerbuilder.co.in/jobsearch?pg=5&loc=&q=student
# Started scraping...
# pg: 6 | q: student |
# https://www.careerbuilder.co.in/jobsearch?pg=6&loc=&q=student
# Started scraping...
# pg: 7 | q: student |
# https://www.careerbuilder.co.in/jobsearch?pg=7&loc=&q=student
# Started scraping...
# pg: 8 | q: student |
# https://www.careerbuilder.co.in/jobsearch?pg=8&loc=&q=student
# Started scraping...
# pg: 9 | q: student |
# https://www.careerbuilder.co.in/jobsearch?pg=9&loc=&q=student
# Started scraping...
# pg: 10 | q: student |
# https://www.careerbuilder.co.in/jobsearch?pg=10&loc=&q=student
# Started scraping...
# pg: 11 | q: student |
# https://www.careerbuilder.co.in/jobsearch?pg=11&loc=&q=student
# Started scraping...
# pg: 12 | q: student |
# https://www.careerbuilder.co.in/jobsearch?pg=12&loc=&q=student
# Started scraping...
# pg: 13 | q: student |
# https://www.careerbuilder.co.in/jobsearch?pg=13&loc=&q=student
# Started scraping...
# pg: 14 | q: student |
# https://www.careerbuilder.co.in/jobsearch?pg=14&loc=&q=student
# pg: 1 | q: panauti gorakhnath youth club |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=panauti+gorakhnath+youth+club
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: maxtech |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=maxtech
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: world vision |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=world+vision
# Total jobs found 143.
# Started scraping...
# pg: 1 | q: world vision |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=world+vision
# Started scraping...
# pg: 2 | q: world vision |
# https://www.careerbuilder.co.in/jobsearch?pg=2&loc=&q=world+vision
# Started scraping...
# pg: 3 | q: world vision |
# https://www.careerbuilder.co.in/jobsearch?pg=3&loc=&q=world+vision
# pg: 1 | q: saim |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=saim
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: bloomon |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=bloomon
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: pasalnepalcom |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=pasalnepalcom
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: frontline consult pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=frontline+consult+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: absolutdata analytics |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=absolutdata+analytics
# Total jobs found 1.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: kaymu nepal pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=kaymu+nepal+pvt+ltd
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: metlife |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=metlife
# Total jobs found 96.
# Started scraping...
# pg: 1 | q: metlife |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=metlife
# Started scraping...
# pg: 2 | q: metlife |
# https://www.careerbuilder.co.in/jobsearch?pg=2&loc=&q=metlife
# pg: 1 | q: self employed |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=self+employed
# Total jobs found 32.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: kaymu asia |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=kaymu+asia
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: mozilla |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=mozilla
# Total jobs found 6.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: buddha bhumi nepal hydro power copvtltd lower tadi khola mw hpp |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=buddha+bhumi+nepal+hydro+power+copvtltd+lower+tadi+khola+mw+hpp
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: honestbee |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=honestbee
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: solid future hr consulting pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=solid+future+hr+consulting+pvt+ltd
# Total jobs found 1.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: seo service nepal |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=seo+service+nepal
# Total jobs found 2.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: respect inc nepal |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=respect+inc+nepal
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: government of nepal ministry of labour and employment occupational health and safety project |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=government+of+nepal+ministry+of+labour+and+employment+occupational+health+and+safety+project
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: ebcg |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=ebcg
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: chilime hydropower company limited |
# https://www.careerbuilder.co.in/jobsearch?pg=0&q=chilime+hydropower+company+limited
# Total jobs found 0.
# No jobs..
# Trying next item in list if any..
#
# pg: 1 | q: tech hall computer pvt ltd |
# https://www.careerbuilder.co.in/jobsearch?pg=1&loc=&q=tech+hall+computer+pvt+ltd
# Total jobs found 1.
# No jobs..
# Trying next item in list if any..

# %%
df = pd.DataFrame(jobs_india.detail)
df.drop_duplicates('id', inplace=True)
df.to_excel(name_file+'.xlsx')
df.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-5837af458eeb> in <module>()
#       1 df = pd.DataFrame(jobs_india.detail)
# ----> 2 df.drop_duplicates('id', inplace=True)
#       3 df.to_excel(name_file+'.xlsx')
#       4 df.shape
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace)
#    3096         """
#    3097         inplace = validate_bool_kwarg(inplace, 'inplace')
# -> 3098         duplicated = self.duplicated(subset, keep=keep)
#    3099
#    3100         if inplace:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    3142
#    3143         vals = (self[col].values for col in subset)
# -> 3144         labels, shape = map(list, zip(*map(f, vals)))
#    3145
#    3146         ids = get_group_index(labels, shape, sort=False, xnull=False)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in <genexpr>(.0)
#    3141             subset = subset,
#    3142
# -> 3143         vals = (self[col].values for col in subset)
#    3144         labels, shape = map(list, zip(*map(f, vals)))
#    3145
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'

# %%
df
# Out:
#                                              company  company_q  date  \
# 0     AzureTeam Software development India Pvt. Ltd.  microsoft     6
# 1                                         Job Finder  microsoft    13
# 2                                         Job Finder  microsoft    13
# 3                                         Job Finder  microsoft    13
# 4                                         Job Finder  microsoft    27
# 5                                         Job Finder  microsoft    28
# 6                                         Job Finder  microsoft    28
# 7                                         Job Finder  microsoft    28
# 8                                         Job Finder  microsoft    28
# 9                      Hexahash Technologies pvt ltd  microsoft     6
# 10                     Hexahash Technologies pvt ltd  microsoft     6
# 11                     Hexahash Technologies pvt ltd  microsoft     6
# 12     Crimson Consulting and Technologies Pvt. Ltd.  microsoft    15
# 13                                        Job Finder  microsoft    27
# 14                                        Job Finder  microsoft    27
# 15                                        Job Finder  microsoft    27
# 16                                        Job Finder  microsoft    27
# 17                                        Job Finder  microsoft    28
# 18                                        Job Finder  microsoft    28
# 19                                        Job Finder  microsoft    28
# 20                                        Job Finder  microsoft    28
# 21                                        Job Finder  microsoft    28
# 22                                        Job Finder  microsoft    28
# 23                                        Job Finder  microsoft    28
# 24                      HR Face Consulting Pvt. Ltd.  microsoft    13
# 25                      HR Face Consulting Pvt. Ltd.  microsoft    13
# 26                      HR Face Consulting Pvt. Ltd.  microsoft    13
# 27                      HR Face Consulting Pvt. Ltd.  microsoft    13
# 28                                           Bask HR  microsoft    13
# 29                                           Bask HR  microsoft    13
# ...                                              ...        ...   ...
# 4191                                 PROPEL SERVICES    metlife    20
# 4192                                 PROPEL SERVICES    metlife    20
# 4193                                 PROPEL SERVICES    metlife    20
# 4194                                 PROPEL SERVICES    metlife    20
# 4195                                 PROPEL SERVICES    metlife    20
# 4196                                 PROPEL SERVICES    metlife    20
# 4197                                 PROPEL SERVICES    metlife    20
# 4198                                 PROPEL SERVICES    metlife    20
# 4199                                 PROPEL SERVICES    metlife    20
# 4200                                 PROPEL SERVICES    metlife    20
# 4201                                 PROPEL SERVICES    metlife    20
# 4202                                 PROPEL SERVICES    metlife    20
# 4203                                 PROPEL SERVICES    metlife    20
# 4204                                 PROPEL SERVICES    metlife    20
# 4205                                 PROPEL SERVICES    metlife    20
# 4206                                 PROPEL SERVICES    metlife    20
# 4207                                 PROPEL SERVICES    metlife    20
# 4208                                 PROPEL SERVICES    metlife    20
# 4209                                 PROPEL SERVICES    metlife    20
# 4210                                 PROPEL SERVICES    metlife    20
# 4211                                 PROPEL SERVICES    metlife    20
# 4212                                 PROPEL SERVICES    metlife    20
# 4213                                 PROPEL SERVICES    metlife    20
# 4214                                 PROPEL SERVICES    metlife    20
# 4215                                 PROPEL SERVICES    metlife    20
# 4216                                 PROPEL SERVICES    metlife    20
# 4217                                 PROPEL SERVICES    metlife    20
# 4218                                 PROPEL SERVICES    metlife    20
# 4219                                 PROPEL SERVICES    metlife    20
# 4220                                 PROPEL SERVICES    metlife    20
#
#           employmentType                                            job_url  \
# 0     Full-Time Employee  /jdp/microsoft-dynamics-365-backend-developer-...
# 1     Full-Time Employee  /jdp/technical-voice-support----microsoft-365-...
# 2     Full-Time Employee  /jdp/technical-voice-support----microsoft-365-...
# 3     Full-Time Employee  /jdp/microsoft-365----technical-voice-support-...
# 4     Full-Time Employee  /jdp/technical-voice-support----microsoft-offi...
# 5     Full-Time Employee  /jdp/microsoft-365----technical-voice-support-...
# 6     Full-Time Employee  /jdp/microsoft-365----technical-voice-support-...
# 7     Full-Time Employee  /jdp/technical-voice-support----microsoft-365-...
# 8     Full-Time Employee  /jdp/technical-voice-support----microsoft-365-...
# 9     Full-Time Employee  /jdp/microsoft-dynamics-crm----senior-level-co...
# 10    Full-Time Employee  /jdp/microsoft-dynamics-crm----senior-level-co...
# 11    Full-Time Employee  /jdp/microsoft-dynamics-crm----senior-level-co...
# 12    Full-Time Employee  /jdp/requirement-of-engg.-grads-mca-for-busine...
# 13    Full-Time Employee  /jdp/microsoft-eps----technical-support-j3f33n...
# 14    Full-Time Employee  /jdp/microsoft-eps----technical-support-j3f7bh...
# 15    Full-Time Employee  /jdp/microsoft-office-365----cloud-computing-j...
# 16    Full-Time Employee  /jdp/microsoft-office-365----cloud-computing-j...
# 17    Full-Time Employee  /jdp/technical-support-executive----microsoft-...
# 18    Full-Time Employee  /jdp/microsoft-office-365----cloud-computing-j...
# 19    Full-Time Employee  /jdp/microsoft-office-365----cloud-computing-j...
# 20    Full-Time Employee  /jdp/technical-support-engineer----microsoft-3...
# 21    Full-Time Employee  /jdp/microsoft-365-process(-technical-voice-su...
# 22    Full-Time Employee  /jdp/microsoft-365-process(-technical-voice-su...
# 23    Full-Time Employee  /jdp/technical-support-engineer----microsoft-3...
# 24    Full-Time Employee             /jdp/microsoft-eps-j3m5166pvh2gw8h54qr
# 25    Full-Time Employee             /jdp/microsoft-eps-j3m84w65vdmc3czt76x
# 26    Full-Time Employee             /jdp/microsoft-eps-j3j0ph74l1g4fwhl0y3
# 27    Full-Time Employee             /jdp/microsoft-eps-j3m5sg6fynvmc5rfgst
# 28    Full-Time Employee  /jdp/ms-crm-developer-ms-dynamics-crm-microsof...
# 29    Full-Time Employee  /jdp/ms-crm-developer-ms-dynamics-crm-microsof...
# ...                  ...                                                ...
# 4191  Full-Time Employee           /jdp/sales-executive-j3f0pn74dzq3npph21v
# 4192  Full-Time Employee           /jdp/sales-executive-j3k17y62drprznz8nq7
# 4193  Full-Time Employee           /jdp/sales-executive-j3g14t6l016l0409nt0
# 4194  Full-Time Employee           /jdp/sales-executive-j3h1sq6fll6tklzm5vt
# 4195  Full-Time Employee           /jdp/sales-executive-j3h7qd6z0qqhkn46d8v
# 4196  Full-Time Employee           /jdp/sales-executive-j3g6rv78tlxznd0567g
# 4197  Full-Time Employee           /jdp/sales-executive-j3g35g6kfd667hrzkc9
# 4198  Full-Time Employee           /jdp/sales-executive-j3h1y16jlnkr4zr85z5
# 4199  Full-Time Employee           /jdp/sales-executive-j3j2sr64524ldlzp3wl
# 4200  Full-Time Employee           /jdp/sales-executive-j3g8gj6nbl5wpgrlkmf
# 4201  Full-Time Employee           /jdp/sales-executive-j3g7sk6825bhfb2rkk2
# 4202  Full-Time Employee           /jdp/sales-executive-j3g4q46t9jkw42s3pb3
# 4203  Full-Time Employee           /jdp/sales-executive-j3h4km6hyh8jx3r1bqw
# 4204  Full-Time Employee           /jdp/sales-executive-j3g7tk6xww9v4xgf85h
# 4205  Full-Time Employee           /jdp/sales-executive-j3l0pn645dh56l239p0
# 4206  Full-Time Employee           /jdp/sales-executive-j3h07y6bdblchhctt9w
# 4207  Full-Time Employee           /jdp/sales-executive-j3h0615xfly2cm7zf53
# 4208  Full-Time Employee           /jdp/sales-executive-j3j4vb68lkq0hqgr6l5
# 4209  Full-Time Employee           /jdp/sales-executive-j3j8bf66gbl7d3fhgvm
# 4210  Full-Time Employee           /jdp/sales-executive-j3l6k26n8q3y0jyqkfk
# 4211  Full-Time Employee           /jdp/sales-executive-j3h75t60nl70p90l5ds
# 4212  Full-Time Employee           /jdp/sales-executive-j3k5r578hcwh4mwytbb
# 4213  Full-Time Employee           /jdp/sales-executive-j3f1p272qjzkg32plwd
# 4214  Full-Time Employee           /jdp/sales-executive-j3f4ml72rfpt0rr21cb
# 4215  Full-Time Employee           /jdp/sales-executive-j3f5kf78p0r2x6qgq7f
# 4216  Full-Time Employee           /jdp/sales-executive-j3f4d85yl6xx5kmdq76
# 4217  Full-Time Employee           /jdp/sales-executive-j3f3dw6l5d4kh7wqmq0
# 4218  Full-Time Employee           /jdp/sales-executive-j3f3vy6r53733xknn6z
# 4219  Full-Time Employee           /jdp/sales-executive-j3f7c2651tw51qcrqvk
# 4220  Full-Time Employee           /jdp/sales-executive-j3h7xw6cv7ywgy0hbqd
#
#                                         location                    query  \
# 0         Ahmedabad, Gujarat, India\n\n\nGUJARAT  pg: 1 | q: microsoft |
# 1                          Pune\n\n\nMAHARASHTRA  pg: 1 | q: microsoft |
# 2                          Gurugram\n\n\nHARYANA  pg: 1 | q: microsoft |
# 3                          Pune\n\n\nMAHARASHTRA  pg: 1 | q: microsoft |
# 4                          Gurugram\n\n\nHARYANA  pg: 1 | q: microsoft |
# 5                          Gurugram\n\n\nHARYANA  pg: 1 | q: microsoft |
# 6                          Pune\n\n\nMAHARASHTRA  pg: 1 | q: microsoft |
# 7                          Pune\n\n\nMAHARASHTRA  pg: 1 | q: microsoft |
# 8                          Gurugram\n\n\nHARYANA  pg: 1 | q: microsoft |
# 9     Hyderabad, Telangana, India\n\n\nTELANGANA  pg: 1 | q: microsoft |
# 10    Bangalore, Karnataka, India\n\n\nKARNATAKA  pg: 1 | q: microsoft |
# 11     Pune, Maharashtra, India\n\n\nMAHARASHTRA  pg: 1 | q: microsoft |
# 12     Pune, Maharashtra, India\n\n\nMAHARASHTRA  pg: 1 | q: microsoft |
# 13                         Gurugram\n\n\nHARYANA  pg: 1 | q: microsoft |
# 14                         Pune\n\n\nMAHARASHTRA  pg: 1 | q: microsoft |
# 15                         Gurugram\n\n\nHARYANA  pg: 1 | q: microsoft |
# 16                         Pune\n\n\nMAHARASHTRA  pg: 1 | q: microsoft |
# 17                         Pune\n\n\nMAHARASHTRA  pg: 1 | q: microsoft |
# 18                         Gurugram\n\n\nHARYANA  pg: 1 | q: microsoft |
# 19                         Pune\n\n\nMAHARASHTRA  pg: 1 | q: microsoft |
# 20                         Pune\n\n\nMAHARASHTRA  pg: 1 | q: microsoft |
# 21                         Pune\n\n\nMAHARASHTRA  pg: 1 | q: microsoft |
# 22                         Gurugram\n\n\nHARYANA  pg: 1 | q: microsoft |
# 23                         Gurugram\n\n\nHARYANA  pg: 1 | q: microsoft |
# 24                       Mumbai\n\n\nMAHARASHTRA  pg: 1 | q: microsoft |
# 25                      Noida\n\n\nUTTAR PRADESH  pg: 1 | q: microsoft |
# 26                              Delhi\n\n\nDELHI  pg: 1 | q: microsoft |
# 27                         Pune\n\n\nMAHARASHTRA  pg: 1 | q: microsoft |
# 28                     Vijayawada\n\n\nTELANGANA  pg: 1 | q: microsoft |
# 29                          Vizag\n\n\nTELANGANA  pg: 1 | q: microsoft |
# ...                                          ...                      ...
# 4191                         Cuttack\n\n\nODISHA    pg: 2 | q: metlife |
# 4192                        Rourkela\n\n\nODISHA    pg: 2 | q: metlife |
# 4193                    Bhilai\n\n\nCHHATTISGARH    pg: 2 | q: metlife |
# 4194                      Muzaffarpur\n\n\nBIHAR    pg: 2 | q: metlife |
# 4195                     Bhubaneswar\n\n\nODISHA    pg: 2 | q: metlife |
# 4196                       Ranchi\n\n\nJHARKHAND    pg: 2 | q: metlife |
# 4197                            Patna\n\n\nBIHAR    pg: 2 | q: metlife |
# 4198                     Bhubaneswar\n\n\nODISHA    pg: 2 | q: metlife |
# 4199                        Rourkela\n\n\nODISHA    pg: 2 | q: metlife |
# 4200                         Cuttack\n\n\nODISHA    pg: 2 | q: metlife |
# 4201                            Patna\n\n\nBIHAR    pg: 2 | q: metlife |
# 4202                   Jamshedpur\n\n\nJHARKHAND    pg: 2 | q: metlife |
# 4203                       Ranchi\n\n\nJHARKHAND    pg: 2 | q: metlife |
# 4204            Bokaro Steel City\n\n\nJHARKHAND    pg: 2 | q: metlife |
# 4205                            Patna\n\n\nBIHAR    pg: 2 | q: metlife |
# 4206                        Rourkela\n\n\nODISHA    pg: 2 | q: metlife |
# 4207                         Cuttack\n\n\nODISHA    pg: 2 | q: metlife |
# 4208                     Bhubaneswar\n\n\nODISHA    pg: 2 | q: metlife |
# 4209                   Jamshedpur\n\n\nJHARKHAND    pg: 2 | q: metlife |
# 4210                   Jamshedpur\n\n\nJHARKHAND    pg: 2 | q: metlife |
# 4211                       Ranchi\n\n\nJHARKHAND    pg: 2 | q: metlife |
# 4212            Bokaro Steel City\n\n\nJHARKHAND    pg: 2 | q: metlife |
# 4213                      Muzaffarpur\n\n\nBIHAR    pg: 2 | q: metlife |
# 4214                             Gaya\n\n\nBIHAR    pg: 2 | q: metlife |
# 4215                       Ranchi\n\n\nJHARKHAND    pg: 2 | q: metlife |
# 4216                      Muzaffarpur\n\n\nBIHAR    pg: 2 | q: metlife |
# 4217                            Patna\n\n\nBIHAR    pg: 2 | q: metlife |
# 4218            Bokaro Steel City\n\n\nJHARKHAND    pg: 2 | q: metlife |
# 4219                         Guwahati\n\n\nASSAM    pg: 2 | q: metlife |
# 4220                             Gaya\n\n\nBIHAR    pg: 2 | q: metlife |
#
#      salary                                            summary  \
# 0       N/A  Immediate opening for Microsoft Dynamics 365 b...
# 1       N/A  TOP BPO Microsoft 365 Process Technical Voice ...
# 2       N/A  TOP BPO Microsoft 365 Process Technical Voice ...
# 3       N/A  TOP BPO Microsoft 365 Process Technical Voice ...
# 4       N/A  Microsoft Office 365 / Microsoft EPS Hirings T...
# 5       N/A  TOP BPO Microsoft 365 Process Technical Voice ...
# 6       N/A  TOP BPO Microsoft 365 Process Technical Voice ...
# 7       N/A  TOP BPO Microsoft 365 Process Technical Voice ...
# 8       N/A  TOP BPO Microsoft 365 Process Technical Voice ...
# 9       N/A  Microsoft Dynamics CRM is a major component of...
# 10      N/A  Microsoft Dynamics CRM is a major component of...
# 11      N/A  Microsoft Dynamics CRM is a major component of...
# 12      N/A  Crimson Consulting and Technologies Pvt. Ltd. ...
# 13      N/A  Microsoft EPS process in TOP BPO Technical Voi...
# 14      N/A  Microsoft EPS process in TOP BPO Technical Voi...
# 15      N/A  Top BPO hiring Technical support Engineers Mic...
# 16      N/A  Top BPO hiring Technical support Engineers Mic...
# 17      N/A  Microsoft EPS process in TOP BPO Technical Voi...
# 18      N/A  Top BPO hiring Technical support Engineers Mic...
# 19      N/A  Top BPO hiring Technical support Engineers Mic...
# 20      N/A  Top BPO hiring for Technical Support Engineer ...
# 21      N/A  Technical voice Support Engineer Microsoft Off...
# 22      N/A  Technical voice Support Engineer Microsoft Off...
# 23      N/A  Top BPO hiring for Technical Support Engineer ...
# 24      N/A  Strong Problem Solving and Troubleshooting Ski...
# 25      N/A  Strong Problem Solving and Troubleshooting Ski...
# 26      N/A  Strong Problem Solving and Troubleshooting Ski...
# 27      N/A  Strong Problem Solving and Troubleshooting Ski...
# 28      N/A  Minimum 4+ years hands-on Microsoft Dynamics C...
# 29      N/A  Minimum 4+ years hands-on Microsoft Dynamics C...
# ...     ...                                                ...
# 4191    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4192    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4193    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4194    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4195    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4196    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4197    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4198    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4199    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4200    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4201    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4202    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4203    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4204    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4205    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4206    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4207    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4208    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4209    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4210    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4211    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4212    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4213    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4214    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4215    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4216    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4217    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4218    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4219    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
# 4220    N/A  METLIFE , KOTAK LIFE, BHARTI AXA, AEGON RELIGA...
#
#                                                   title
# 0              Microsoft Dynamics 365 Backend Developer
# 1               Technical Voice Support - Microsoft 365
# 2               Technical Voice Support - Microsoft 365
# 3              Microsoft 365 -  Technical Voice Support
# 4        Technical Voice Support - Microsoft Office 365
# 5               Microsoft 365 - Technical Voice Support
# 6               Microsoft 365 - Technical Voice Support
# 7               Technical Voice Support - Microsoft 365
# 8               Technical Voice Support - Microsoft 365
# 9      Microsoft Dynamics CRM - Senior Level Consultant
# 10     Microsoft Dynamics CRM - Senior Level Consultant
# 11     Microsoft Dynamics CRM - Senior Level Consultant
# 12    Requirement of Engg. Grads/MCA for Business An...
# 13                    Microsoft Eps - Technical Support
# 14                    Microsoft Eps - Technical Support
# 15               Microsoft Office 365 - Cloud Computing
# 16               Microsoft Office 365 - Cloud Computing
# 17          Technical Support Executive - Microsoft Eps
# 18               Microsoft Office 365 - Cloud Computing
# 19               Microsoft Office 365 - Cloud Computing
# 20           Technical Support Engineer - microsoft 365
# 21      Microsoft 365 Process( Technical Voice Support)
# 22      Microsoft 365 Process( Technical Voice Support)
# 23           Technical Support Engineer - microsoft 365
# 24                                        Microsoft EPS
# 25                                        Microsoft EPS
# 26                                        Microsoft EPS
# 27                                        Microsoft EPS
# 28    MS CRM Developer MS Dynamics CRM Microsoft Dyn...
# 29    MS CRM Developer MS Dynamics CRM Microsoft Dyn...
# ...                                                 ...
# 4191                                    Sales Executive
# 4192                                    Sales Executive
# 4193                                    Sales Executive
# 4194                                    Sales Executive
# 4195                                    Sales Executive
# 4196                                    Sales Executive
# 4197                                    Sales Executive
# 4198                                    Sales Executive
# 4199                                    Sales Executive
# 4200                                    Sales Executive
# 4201                                    Sales Executive
# 4202                                    Sales Executive
# 4203                                    Sales Executive
# 4204                                    Sales Executive
# 4205                                    Sales Executive
# 4206                                    Sales Executive
# 4207                                    Sales Executive
# 4208                                    Sales Executive
# 4209                                    Sales Executive
# 4210                                    Sales Executive
# 4211                                    Sales Executive
# 4212                                    Sales Executive
# 4213                                    Sales Executive
# 4214                                    Sales Executive
# 4215                                    Sales Executive
# 4216                                    Sales Executive
# 4217                                    Sales Executive
# 4218                                    Sales Executive
# 4219                                    Sales Executive
# 4220                                    Sales Executive
#
# [4221 rows x 10 columns]

# %% [markdown]
# ---
